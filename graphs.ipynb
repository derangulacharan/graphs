# %%
import numpy as np

# %%
import pandas as pd

# %%
num=-1
if (num > 0)
print(num,"is greater  than zero")
else:
print(num,"is less than zero")
# Out:
#   File "<ipython-input-5-b63727752862>", line 2
#     if (num > 0)
#                 ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt

# %%
xpoints = np.array([1,2])
ypoints = np.array([5,10])
plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints = np.array([1,20])
ypoints = np.array([10,200])
plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints = np.array([2,10])
ypoints = np.array([20,30])
plt.plot(xpoints, ypoints,"*")
plt.show()

# %%
xpoints = np.array([20,40])
ypoints = np.array([60,80])
plt.plot(xpoints, ypoints,"y","y")
plt.show()

# %%
xpoints = np.array([20,40])
ypoints = np.array([60,80])
plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints = np.array([20,40])
ypoints = np.array([60,80])
plt.plot(xpoints, ypoints,"*")
plt.show()

# %%
ypoints = np.array([2,3,4,5,1])
plt.plot(ypoints,'*''r')
plt.show()

# %%
ypoints = np.array([2,3,4,5,1])
plt.plot(ypoints,'*''g')
plt.show()

# %%
xpoints = np.array([2,3,4,5,6])
ypoints = np.array([0,2,0,2,0])
plt.plot(xpoints,ypoints, marker='*',ms=50,color='pink')
plt.show()

# %%
ypoints = np.array([3,4,0,6])
plt.plot(ypoints, marker= 'o', ms= 50, mec='k',color='pink')
plt.show()

# %%
ypoints = np.array([4,5,6,7])
plt.plot(ypoints, mec='b',marker='o',ms=40,mfc='r')
plt.show()

# %%
ypoints=np.array([1,2,3,4])
plt.plot(ypoints,linestyle='dashed',marker='o',mec='pink',ms=30,mfc='green',linewidth=6)
plt.show()

# %%
ypoints=np.array([1,2,3,4])
plt.plot(ypoints,linestyle='dotted',marker='o',mec='pink',ms=30,mfc='green',linewidth=3)
plt.show()

# %%
xpoints=np.array([1,2,3,4,5])
ypoints=np.array([3,4,3,4,3])
plt.plot(xpoints,ypoints,marker='*',color="g",mfc="pink",mec="r",ms=50,linestyle="dotted")

# %%
y1=np.array([3,4,5,6])
y2=np.array([1,2,3,4])
plt.plot(y1)
plt.plot(y2)
plt.plot(y1,y2,"o")
plt.show()

# %%
y1=np.array([3,4,5,6,3,6])
y2=np.array([1,2,3,4])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
y1=np.array([3,4,5,6,3,6])
y2=np.array([1,2,3,4])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
C

# %%
y1=np.array([3,4,5,6,3,6])
y2=np.array([1,2,3,4])
plt.plot(y1,marker='*',color='green',mec='red',mfc='yellow',ms=50,linestyle="dotted",linewidth=6)
plt.plot(y2)
plt.show()
